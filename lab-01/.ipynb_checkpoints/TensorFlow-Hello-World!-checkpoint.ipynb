# %% [markdown]
# # Hello TensorFlow!
# 텐서플로우 시작하기!

# %%
import tensorflow as tf

# 텐서플로우 버전 출력
tf.__version__
# Out:
# '1.12.0'

# %% [markdown]
# `constant` 상수 입력
# `session run`을 통해 그래프를 런 하거나, 값을 출력함

# %%
hello = tf.constant("Hello, TensorFlow!")

sess = tf.Session()

print(sess.run(hello))
# Out:
# b'Hello, TensorFlow!'
