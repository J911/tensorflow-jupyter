# %% [markdown]
# # Hello TensorFlow!

# %%
import tensorflow as tf

tf.__version__
# Out:
# '1.12.0'

# %%
hello = tf.constant("Hello, TensorFlow!")

sess = tf.Session()

print(sess.run(hello))
# Out:
# b'Hello, TensorFlow!'
