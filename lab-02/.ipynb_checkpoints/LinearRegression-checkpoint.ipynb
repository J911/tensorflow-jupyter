# %%
import tensorflow as tf

# %% [markdown]
# `Variable`을 통해 변수를 생성할 수 있음 여기서 변수는 train되면서 새로 변화는 값
# `Variable`을 사용하기 위해서는 `sess.run(tf.global_variables_initializer())`을 해야함

# %%
x_train = [1, 2, 3]
y_train = [1, 2, 3]

W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = x_train * W + b

# %% [markdown]
# linear regression의 코스트 값을 구하는 부분

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 2.7321377 [1.0914861] [-1.8342015]
# 20 0.3429292 [1.6013355] [-1.5218256]
# 40 0.29206517 [1.6220318] [-1.4287691]
# 60 0.26508248 [1.5974602] [-1.3595717]
# 80 0.24075055 [1.5698256] [-1.2954813]
# 100 0.21865356 [1.5430882] [-1.23458]
# 120 0.19858466 [1.5175692] [-1.1765575]
# 140 0.18035765 [1.4932456] [-1.1212634]
# 160 0.16380382 [1.470065] [-1.0685683]
# 180 0.14876936 [1.4479738] [-1.0183498]
# 200 0.13511463 [1.4269207] [-0.9704911]
# 220 0.122713305 [1.406857] [-0.92488164]
# 240 0.111450166 [1.3877361] [-0.88141567]
# 260 0.10122088 [1.3695141] [-0.8399923]
# 280 0.09193045 [1.3521483] [-0.8005157]
# 300 0.083492674 [1.3355986] [-0.7628945]
# 320 0.07582936 [1.3198266] [-0.7270412]
# 340 0.06886944 [1.3047959] [-0.6928728]
# 360 0.06254834 [1.2904717] [-0.6603103]
# 380 0.056807365 [1.2768205] [-0.6292782]
# 400 0.051593333 [1.263811] [-0.59970427]
# 420 0.04685788 [1.2514127] [-0.5715203]
# 440 0.04255712 [1.2395974] [-0.54466105]
# 460 0.038651053 [1.2283372] [-0.51906407]
# 480 0.035103496 [1.2176061] [-0.4946699]
# 500 0.031881567 [1.2073795] [-0.47142223]
# 520 0.028955331 [1.1976334] [-0.44926706]
# 540 0.026297713 [1.1883454] [-0.42815325]
# 560 0.023883998 [1.1794937] [-0.40803155]
# 580 0.02169183 [1.1710582] [-0.38885555]
# 600 0.019700887 [1.1630193] [-0.3705808]
# 620 0.017892642 [1.1553578] [-0.35316488]
# 640 0.016250396 [1.1480566] [-0.33656746]
# 660 0.01475885 [1.1410983] [-0.32075]
# 680 0.013404218 [1.1344674] [-0.3056759]
# 700 0.012173937 [1.1281478] [-0.29131028]
# 720 0.011056556 [1.1221253] [-0.27761972]
# 740 0.010041726 [1.1163858] [-0.26457244]
# 760 0.009120052 [1.1109161] [-0.2521384]
# 780 0.008282993 [1.1057035] [-0.24028884]
# 800 0.0075227446 [1.1007359] [-0.22899614]
# 820 0.0068322676 [1.0960015] [-0.21823417]
# 840 0.0062051774 [1.0914899] [-0.20797794]
# 860 0.0056356303 [1.0871902] [-0.19820371]
# 880 0.0051183803 [1.0830925] [-0.18888888]
# 900 0.004648576 [1.0791873] [-0.18001169]
# 920 0.0042219195 [1.0754659] [-0.17155176]
# 940 0.0038344099 [1.0719193] [-0.16348942]
# 960 0.0034824766 [1.0685394] [-0.15580603]
# 980 0.0031628392 [1.0653182] [-0.14848368]
# 1000 0.0028725422 [1.0622487] [-0.1415055]
# 1020 0.0026088932 [1.059323] [-0.13485534]
# 1040 0.0023694306 [1.056535] [-0.12851758]
# 1060 0.0021519507 [1.0538781] [-0.12247768]
# 1080 0.0019544417 [1.0513461] [-0.11672169]
# 1100 0.0017750581 [1.048933] [-0.11123619]
# 1120 0.0016121325 [1.0466332] [-0.10600851]
# 1140 0.0014641633 [1.0444417] [-0.10102648]
# 1160 0.0013297807 [1.0423533] [-0.09627862]
# 1180 0.0012077227 [1.0403625] [-0.09175386]
# 1200 0.0010968731 [1.0384657] [-0.0874417]
# 1220 0.0009961977 [1.0366579] [-0.08333223]
# 1240 0.0009047606 [1.0349352] [-0.07941593]
# 1260 0.00082172436 [1.0332934] [-0.07568369]
# 1280 0.0007463002 [1.0317287] [-0.07212684]
# 1300 0.00067780045 [1.0302374] [-0.0687371]
# 1320 0.00061558717 [1.0288165] [-0.06550666]
# 1340 0.0005590879 [1.0274622] [-0.06242806]
# 1360 0.00050776964 [1.0261716] [-0.0594942]
# 1380 0.0004611656 [1.0249417] [-0.05669821]
# 1400 0.00041884126 [1.0237695] [-0.05403359]
# 1420 0.00038039463 [1.0226525] [-0.05149427]
# 1440 0.00034548668 [1.021588] [-0.04907429]
# 1460 0.0003137748 [1.0205735] [-0.04676814]
# 1480 0.00028497932 [1.0196067] [-0.04457024]
# 1500 0.0002588189 [1.0186849] [-0.04247551]
# 1520 0.00023506275 [1.0178068] [-0.04047923]
# 1540 0.00021348723 [1.0169699] [-0.03857682]
# 1560 0.0001938917 [1.0161724] [-0.03676382]
# 1580 0.00017609529 [1.0154123] [-0.03503603]
# 1600 0.00015993282 [1.014688] [-0.03338941]
# 1620 0.00014525319 [1.0139978] [-0.03182025]
# 1640 0.00013192109 [1.0133398] [-0.03032476]
# 1660 0.0001198116 [1.012713] [-0.02889957]
# 1680 0.00010881558 [1.0121155] [-0.0275414]
# 1700 9.8827964e-05 [1.0115461] [-0.02624705]
# 1720 8.975807e-05 [1.0110035] [-0.02501355]
# 1740 8.151872e-05 [1.0104864] [-0.02383799]
# 1760 7.403696e-05 [1.0099936] [-0.02271774]
# 1780 6.724086e-05 [1.0095239] [-0.02164999]
# 1800 6.1069535e-05 [1.0090764] [-0.02063252]
# 1820 5.546365e-05 [1.0086497] [-0.01966288]
# 1840 5.037378e-05 [1.0082432] [-0.01873878]
# 1860 4.5750014e-05 [1.0078558] [-0.01785813]
# 1880 4.1550924e-05 [1.0074866] [-0.01701883]
# 1900 3.773632e-05 [1.0071348] [-0.01621903]
# 1920 3.427288e-05 [1.0067996] [-0.01545682]
# 1940 3.1127933e-05 [1.0064799] [-0.0147304]
# 1960 2.8270288e-05 [1.0061754] [-0.01403811]
# 1980 2.5675587e-05 [1.0058851] [-0.01337835]
# 2000 2.3318653e-05 [1.0056086] [-0.01274958]
