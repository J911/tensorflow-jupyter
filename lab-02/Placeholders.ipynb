# %%
import tensorflow as tf

# %%
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

# %%
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = X * W + b
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], feed_dict={X: [1, 2, 3], Y: [2.1, 3.1, 4.1]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 1.2084025 [1.0413405] [0.02804559]
# 20 0.1190876 [1.3485947] [0.21443982]
# 40 0.09928638 [1.3616534] [0.2690093]
# 60 0.090092964 [1.3474605] [0.30929607]
# 80 0.081823185 [1.3313981] [0.34657362]
# 100 0.0743131 [1.3158488] [0.38199311]
# 120 0.06749236 [1.3010076] [0.415738]
# 140 0.061297584 [1.2868615] [0.4478959]
# 160 0.05567151 [1.2733802] [0.47854245]
# 180 0.050561707 [1.2605323] [0.5077487]
# 200 0.045920923 [1.2482883] [0.5355824]
# 220 0.04170612 [1.2366196] [0.5621079]
# 240 0.03787821 [1.2254995] [0.58738685]
# 260 0.03440161 [1.2149017] [0.61147773]
# 280 0.031244084 [1.2048022] [0.6344365]
# 300 0.028376332 [1.1951772] [0.6563163]
# 320 0.02577187 [1.1860046] [0.6771677]
# 340 0.023406425 [1.1772631] [0.6970392]
# 360 0.021258099 [1.1689324] [0.7159767]
# 380 0.01930697 [1.1609931] [0.7340244]
# 400 0.017534904 [1.1534272] [0.7512239]
# 420 0.015925447 [1.1462166] [0.76761514]
# 440 0.014463772 [1.139345] [0.7832359]
# 460 0.013136237 [1.1327964] [0.79812264]
# 480 0.011930556 [1.1265554] [0.81230974]
# 500 0.010835492 [1.1206076] [0.82583016]
# 520 0.00984095 [1.1149396] [0.83871526]
# 540 0.008937717 [1.1095378] [0.8509947]
# 560 0.008117393 [1.10439] [0.86269706]
# 580 0.0073723183 [1.099484] [0.87384945]
# 600 0.0066956864 [1.0948086] [0.8844776]
# 620 0.0060811206 [1.090353] [0.8946064]
# 640 0.0055229696 [1.0861067] [0.90425915]
# 660 0.0050160494 [1.08206] [0.9134583]
# 680 0.004555654 [1.0782034] [0.922225]
# 700 0.004137524 [1.0745282] [0.93057966]
# 720 0.003757771 [1.0710255] [0.9385419]
# 740 0.0034128584 [1.0676877] [0.94612986]
# 760 0.003099611 [1.0645066] [0.95336115]
# 780 0.0028151094 [1.0614749] [0.96025264]
# 800 0.0025567291 [1.0585858] [0.9668203]
# 820 0.0023220542 [1.0558325] [0.9730793]
# 840 0.0021089423 [1.0532086] [0.9790441]
# 860 0.0019153714 [1.050708] [0.9847285]
# 880 0.0017395731 [1.048325] [0.99014586]
# 900 0.0015799109 [1.046054] [0.99530864]
# 920 0.0014349017 [1.0438895] [1.0002288]
# 940 0.0013031916 [1.041827] [1.0049176]
# 960 0.0011835904 [1.0398611] [1.0093861]
# 980 0.001074951 [1.0379878] [1.0136447]
# 1000 0.00097627536 [1.0362025] [1.0177033]
# 1020 0.0008866635 [1.0345011] [1.021571]
# 1040 0.00080528966 [1.0328796] [1.0252569]
# 1060 0.0007313813 [1.0313344] [1.0287695]
# 1080 0.0006642458 [1.0298618] [1.0321169]
# 1100 0.0006032821 [1.0284585] [1.0353073]
# 1120 0.00054791104 [1.0271211] [1.0383474]
# 1140 0.0004976248 [1.0258465] [1.0412447]
# 1160 0.0004519512 [1.0246319] [1.044006]
# 1180 0.00041046788 [1.0234742] [1.0466374]
# 1200 0.00037279897 [1.0223712] [1.0491451]
# 1220 0.00033858255 [1.02132] [1.0515351]
# 1240 0.0003075005 [1.0203176] [1.0538129]
# 1260 0.0002792796 [1.0193627] [1.0559837]
# 1280 0.00025364014 [1.0184526] [1.0580523]
# 1300 0.00023035657 [1.0175855] [1.060024]
# 1320 0.00020921294 [1.0167589] [1.0619028]
# 1340 0.00019001226 [1.0159713] [1.0636932]
# 1360 0.00017257466 [1.0152209] [1.0653993]
# 1380 0.00015673552 [1.0145055] [1.0670254]
# 1400 0.00014234956 [1.0138239] [1.068575]
# 1420 0.00012928197 [1.0131742] [1.070052]
# 1440 0.00011741726 [1.0125549] [1.0714595]
# 1460 0.00010663804 [1.0119648] [1.072801]
# 1480 9.685089e-05 [1.0114025] [1.0740793]
# 1500 8.7961474e-05 [1.0108668] [1.0752974]
# 1520 7.989069e-05 [1.0103562] [1.0764582]
# 1540 7.255551e-05 [1.0098695] [1.0775645]
# 1560 6.589819e-05 [1.0094056] [1.0786186]
# 1580 5.985091e-05 [1.0089636] [1.0796236]
# 1600 5.435864e-05 [1.0085424] [1.080581]
# 1620 4.936835e-05 [1.0081409] [1.0814937]
# 1640 4.4836295e-05 [1.0077584] [1.0823634]
# 1660 4.0721163e-05 [1.0073937] [1.0831922]
# 1680 3.6983314e-05 [1.0070463] [1.0839821]
# 1700 3.3589968e-05 [1.0067152] [1.0847349]
# 1720 3.0506375e-05 [1.0063995] [1.0854523]
# 1740 2.770552e-05 [1.0060987] [1.086136]
# 1760 2.5162788e-05 [1.005812] [1.0867877]
# 1780 2.2854068e-05 [1.005539] [1.0874087]
# 1800 2.0756632e-05 [1.0052786] [1.0880004]
# 1820 1.8851335e-05 [1.0050306] [1.0885642]
# 1840 1.7121056e-05 [1.0047942] [1.0891016]
# 1860 1.5549089e-05 [1.0045689] [1.0896137]
# 1880 1.4122226e-05 [1.0043544] [1.0901017]
# 1900 1.2827067e-05 [1.0041496] [1.090567]
# 1920 1.1649522e-05 [1.0039546] [1.0910102]
# 1940 1.0579483e-05 [1.0037688] [1.0914327]
# 1960 9.609105e-06 [1.0035917] [1.0918353]
# 1980 8.7273465e-06 [1.0034229] [1.0922189]
# 2000 7.926293e-06 [1.003262] [1.0925846]
