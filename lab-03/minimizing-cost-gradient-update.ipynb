# %%
import tensorflow as tf

# %%
x_data = [1, 2, 3]
y_data = [1, 2, 3]

# %%
W = tf.Variable(tf.random_normal([1]), name='weight')
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

# %%
hypothesis = X * W
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
learning_rate = 0.1
gradinet = tf.reduce_mean((W * X - Y) * X)
descent = W - learning_rate * gradinet
update = W.assign(descent)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(21):
    sess.run(update, feed_dict={X: x_data, Y: y_data})
    print(step, sess.run(cost, feed_dict={X: x_data, Y: y_data}), sess.run(W))
# Out:
# 0 10.112967 [-0.47209513]
# 1 2.8765764 [0.21488267]
# 2 0.8182264 [0.5812707]
# 3 0.23273985 [0.7766777]
# 4 0.06620156 [0.8808948]
# 5 0.018830692 [0.9364772]
# 6 0.0053562983 [0.96612114]
# 7 0.0015235668 [0.98193127]
# 8 0.00043336928 [0.99036336]
# 9 0.0001232683 [0.9948605]
# 10 3.5063564e-05 [0.9972589]
# 11 9.973516e-06 [0.9985381]
# 12 2.8370248e-06 [0.9992203]
# 13 8.068261e-07 [0.9995842]
# 14 2.295812e-07 [0.9997782]
# 15 6.526049e-08 [0.99988174]
# 16 1.8573346e-08 [0.99993694]
# 17 5.2738187e-09 [0.9999664]
# 18 1.5042438e-09 [0.99998206]
# 19 4.2443085e-10 [0.99999046]
# 20 1.2039081e-10 [0.99999493]
