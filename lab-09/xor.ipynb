# %%
import tensorflow as tf
import numpy as np

# %%
x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0],[1],[1],[0]], dtype=np.float32)

# %%
X = tf.placeholder(tf.float32, [None, 2])
Y = tf.placeholder(tf.float32, [None, 1])
W = tf.Variable(tf.random_normal([2, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
hypothesis = tf.sigmoid(tf.matmul(X, W) + b)

cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1 - Y) * tf.log(1 - hypothesis))
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# %%
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    for step in range(10001):
        _, cost_val, w_val = sess.run([train, cost, W], feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step, cost_val, w_val)

    h, c, a = sess.run([hypothesis, predicted, accuracy], feed_dict={X: x_data, Y: y_data})
    print("\nHypothesis: ", h, "\nCorrect: ", c, "\nAccuracy: ", a)
# Out:
# 0 0.7293148 [[-0.14283974]
#  [ 0.63931084]]
# 100 0.69619334 [[-0.14830498]
#  [ 0.27278528]]
# 200 0.6940577 [[-0.07251614]
#  [ 0.152737  ]]
# 300 0.69342566 [[-0.03314503]
#  [ 0.0872346 ]]
# 400 0.69323504 [[-0.01390293]
#  [ 0.05041255]]
# 500 0.6931761 [[-0.00485802]
#  [ 0.02950123]]
# 600 0.69315714 [[-0.00086095]
#  [ 0.01749436]]
# 700 0.69315076 [[0.00071065]
#  [0.01051633]]
# 800 0.6931486 [[0.00116974]
#  [0.00640807]]
# 900 0.6931478 [[0.00115819]
#  [0.00395657]]
# 1000 0.6931474 [[0.00097869]
#  [0.00247361]]
# 1100 0.6931473 [[0.00076578]
#  [0.0015644 ]]
# 1200 0.69314724 [[0.00057309]
#  [0.0009997 ]]
# 1300 0.6931472 [[0.00041686]
#  [0.00064473]]
# 1400 0.6931472 [[0.00029742]
#  [0.00041914]]
# 1500 0.6931472 [[0.0002093 ]
#  [0.00027434]]
# 1600 0.6931472 [[0.00014583]
#  [0.00018058]]
# 1700 0.69314724 [[0.00010086]
#  [0.00011944]]
# 1800 0.6931472 [[6.9387694e-05]
#  [7.9299687e-05]]
# 1900 0.6931472 [[4.7526191e-05]
#  [5.2817333e-05]]
# 2000 0.6931472 [[3.2444732e-05]
#  [3.5271216e-05]]
# 2100 0.6931471 [[2.2097374e-05]
#  [2.3606593e-05]]
# 2200 0.6931472 [[1.5013373e-05]
#  [1.5819242e-05]]
# 2300 0.6931472 [[1.0189866e-05]
#  [1.0624700e-05]]
# 2400 0.6931472 [[6.8922482e-06]
#  [7.1408135e-06]]
# 2500 0.6931472 [[4.6645255e-06]
#  [4.7998456e-06]]
# 2600 0.6931472 [[3.1639759e-06]
#  [3.2009443e-06]]
# 2700 0.6931472 [[2.1343030e-06]
# 6500 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 6600 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 6700 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 6800 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 6900 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 7000 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 7100 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 7200 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 7300 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 7400 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 7500 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 7600 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 7700 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 7800 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 7900 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 8000 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 8100 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 8200 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 8300 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 8400 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 8500 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 8600 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 8700 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 8800 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 8900 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 9000 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 9100 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 9200 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 9300 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 9400 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 9500 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 9600 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 9700 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 9800 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 9900 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
# 10000 0.6931472 [[1.3158052e-07]
#  [1.3278660e-07]]
#
# Hypothesis:  [[0.5]
#  [0.5]
#  [0.5]
#  [0.5]]
# Correct:  [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Accuracy:  0.5
